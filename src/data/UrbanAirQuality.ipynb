# %% [markdown]
# #### Jogja Code ALL

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, LSTM, GRU, Dense, SimpleRNN
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pickle

# Load the datasets
data1 = pd.read_csv('jogja2023.csv', delimiter=';')
data2 = pd.read_csv('jogja2022.csv', delimiter=';')
data3 = pd.read_csv('jogja2021.csv', delimiter=';')
data4 = pd.read_csv('jogja2020.csv')

# Preprocess the data (assuming both datasets have the same structure)
data1['Date'] = pd.to_datetime(data1['Waktu'], format='%d/%m/%Y', errors='coerce')
data2['Date'] = pd.to_datetime(data2['Waktu'], format='%d/%m/%Y', errors='coerce')
data3['Date'] = pd.to_datetime(data3['Waktu'], format='%d/%m/%Y', errors='coerce')
data4['Date'] = pd.to_datetime(data4['Date'], format='%m/%d/%Y', errors='coerce')

# Drop rows with invalid dates
data1.dropna(subset=['Waktu'], inplace=True)
data2.dropna(subset=['Waktu'], inplace=True)
data3.dropna(subset=['Waktu'], inplace=True)
data4.dropna(subset=['Date'], inplace=True)

# Set the 'Date' column as the index for all datasets
data1.set_index('Waktu', inplace=True)
data2.set_index('Waktu', inplace=True)
data3.set_index('Waktu', inplace=True)
data4.set_index('Date', inplace=True)

# Select relevant columns from data4 and rename them to match the other datasets
data4 = data4[['PM10', 'SO2', 'CO', 'O3', 'NO2']]
data4['PM2.5'] = np.nan  # Add PM2.5 column with NaN values to match other datasets

# Concatenate the datasets
data = pd.concat([data1, data2, data3, data4])

# Replace commas with periods and '-' with NaN, then convert to float
for col in ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']:
    data[col] = data[col].astype(str).str.replace(',', '.').replace('-', np.nan).astype(float)

# Remove rows with 0 data
data = data[(data[['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']] != 0).all(axis=1)]

# Handle NaN values in the numeric columns only
numeric_columns = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')

# Select features and target
features = data[numeric_columns]
target = data[numeric_columns]

# Normalize the features and target
scaler_features = MinMaxScaler()
features_scaled = scaler_features.fit_transform(features)

scaler_target = MinMaxScaler()
target_scaled = scaler_target.fit_transform(target)

# Prepare the data for time series models with sequence length of 5 days
def create_sequences(data, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(target[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 5
X, y = create_sequences(features_scaled, target_scaled, seq_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Function to evaluate the model for each pollutant with additional metrics
def evaluate_model_per_pollutant(y_true, y_pred):
    metrics = {}
    for i, pollutant in enumerate(numeric_columns):
        mse = mean_squared_error(y_true[:, i], y_pred[:, i])
        mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true[:, i], y_pred[:, i])
        mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
        mbd = np.mean(y_pred[:, i] - y_true[:, i])
        smape = 100/len(y_true) * np.sum(2 * np.abs(y_pred[:, i] - y_true[:, i]) / (np.abs(y_true[:, i]) + np.abs(y_pred[:, i])))
        metrics[pollutant] = {'MSE': mse, 'MAE': mae, 'RMSE': rmse, 'R-squared': r2, 'MAPE': mape, 'MBD': mbd, 'sMAPE': smape}
    return metrics

# CNN Model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(seq_length, X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(y.shape[1]))
cnn_model.compile(optimizer='adam', loss='mean_squared_error')
cnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
cnn_predictions_scaled = cnn_model.predict(X_test)
cnn_predictions = scaler_target.inverse_transform(cnn_predictions_scaled)
cnn_metrics = evaluate_model_per_pollutant(y_test, cnn_predictions_scaled)

# RNN Model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
rnn_model.add(SimpleRNN(64))
rnn_model.add(Dense(y.shape[1]))
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
rnn_predictions_scaled = rnn_model.predict(X_test)
rnn_predictions = scaler_target.inverse_transform(rnn_predictions_scaled)
rnn_metrics = evaluate_model_per_pollutant(y_test, rnn_predictions_scaled)

# GRU Model
gru_model = Sequential()
gru_model.add(GRU(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
gru_model.add(GRU(64))
gru_model.add(Dense(y.shape[1]))
gru_model.compile(optimizer='adam', loss='mean_squared_error')
gru_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
gru_predictions_scaled = gru_model.predict(X_test)
gru_predictions = scaler_target.inverse_transform(gru_predictions_scaled)
gru_metrics = evaluate_model_per_pollutant(y_test, gru_predictions_scaled)

# LSTM Model
lstm_model = Sequential()
lstm_model.add(LSTM(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
lstm_model.add(LSTM(64))
lstm_model.add(Dense(y.shape[1]))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
lstm_predictions_scaled = lstm_model.predict(X_test)
lstm_predictions = scaler_target.inverse_transform(lstm_predictions_scaled)
lstm_metrics = evaluate_model_per_pollutant(y_test, lstm_predictions_scaled)

# SARIMA Model (only for PM2.5)
sarima_model = SARIMAX(data['PM2.5'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)
sarima_predictions = sarima_fit.predict(start=len(data) - len(y_test), end=len(data) - 1)
sarima_metrics = {
    'PM2.5': {
        'MSE': mean_squared_error(y_test[:, 0], sarima_predictions),
        'MAE': mean_absolute_error(y_test[:, 0], sarima_predictions),
        'RMSE': np.sqrt(mean_squared_error(y_test[:, 0], sarima_predictions)),
        'R-squared': r2_score(y_test[:, 0], sarima_predictions),
        'MAPE': np.mean(np.abs((y_test[:, 0] - sarima_predictions) / y_test[:, 0])) * 100,
        'MBD': np.mean(sarima_predictions - y_test[:, 0]),
        'sMAPE': 100/len(y_test) * np.sum(2 * np.abs(sarima_predictions - y_test[:, 0]) / (np.abs(y_test[:, 0]) + np.abs(sarima_predictions)))
    }
}

# Print evaluation metrics for each pollutant and model
print("CNN Metrics:")
for pollutant in cnn_metrics:
    print(f"{pollutant} - MSE: {cnn_metrics[pollutant]['MSE']}, MAE: {cnn_metrics[pollutant]['MAE']}, RMSE: {cnn_metrics[pollutant]['RMSE']}, R-squared: {cnn_metrics[pollutant]['R-squared']}, MAPE: {cnn_metrics[pollutant]['MAPE']}, MBD: {cnn_metrics[pollutant]['MBD']}, sMAPE: {cnn_metrics[pollutant]['sMAPE']}")

print("\nRNN Metrics:")
for pollutant in rnn_metrics:
    print(f"{pollutant} - MSE: {rnn_metrics[pollutant]['MSE']}, MAE: {rnn_metrics[pollutant]['MAE']}, RMSE: {rnn_metrics[pollutant]['RMSE']}, R-squared: {rnn_metrics[pollutant]['R-squared']}, MAPE: {rnn_metrics[pollutant]['MAPE']}, MBD: {rnn_metrics[pollutant]['MBD']}, sMAPE: {rnn_metrics[pollutant]['sMAPE']}")

print("\nGRU Metrics:")
for pollutant in gru_metrics:
    print(f"{pollutant} - MSE: {gru_metrics[pollutant]['MSE']}, MAE: {gru_metrics[pollutant]['MAE']}, RMSE: {gru_metrics[pollutant]['RMSE']}, R-squared: {gru_metrics[pollutant]['R-squared']}, MAPE: {gru_metrics[pollutant]['MAPE']}, MBD: {gru_metrics[pollutant]['MBD']}, sMAPE: {gru_metrics[pollutant]['sMAPE']}")

print("\nLSTM Metrics:")
for pollutant in lstm_metrics:
    print(f"{pollutant} - MSE: {lstm_metrics[pollutant]['MSE']}, MAE: {lstm_metrics[pollutant]['MAE']}, RMSE: {lstm_metrics[pollutant]['RMSE']}, R-squared: {lstm_metrics[pollutant]['R-squared']}, MAPE: {lstm_metrics[pollutant]['MAPE']}, MBD: {lstm_metrics[pollutant]['MBD']}, sMAPE: {lstm_metrics[pollutant]['sMAPE']}")

print("\nSARIMA Metrics (only for PM2.5):")
for pollutant in sarima_metrics:
    print(f"{pollutant} - MSE: {sarima_metrics[pollutant]['MSE']}, MAE: {sarima_metrics[pollutant]['MAE']}, RMSE: {sarima_metrics[pollutant]['RMSE']}, R-squared: {sarima_metrics[pollutant]['R-squared']}, MAPE: {sarima_metrics[pollutant]['MAPE']}, MBD: {sarima_metrics[pollutant]['MBD']}, sMAPE: {sarima_metrics[pollutant]['sMAPE']}")

# Plot each pollutant over time and compare actual vs predicted values for test set
pollutants = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
for pollutant in pollutants:
    plt.figure(figsize=(12, 6))
    plt.plot(data.index[-len(X_test):], scaler_target.inverse_transform(y_test)[:, pollutants.index(pollutant)], label=f'Actual {pollutant}')
    plt.plot(data.index[-len(X_test):], cnn_predictions[:, pollutants.index(pollutant)], label=f'CNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], rnn_predictions[:, pollutants.index(pollutant)], label=f'RNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], gru_predictions[:, pollutants.index(pollutant)], label=f'GRU Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], lstm_predictions[:, pollutants.index(pollutant)], label=f'LSTM Predicted {pollutant}')
    if pollutant == 'PM2.5':
        plt.plot(data.index[-len(X_test):], sarima_predictions, label=f'SARIMA Predicted {pollutant}')
    
    # Adjust x-axis ticks
    plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks every year
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format ticks as year only
    plt.gca().xaxis.set_minor_locator(mdates.MonthLocator())  # Set minor ticks every month (optional)
    
    # Rotate the x-axis labels for better readability
    plt.xticks(rotation=45)
    
    plt.title(f'{pollutant} over Time (Actual vs Predicted)')
    plt.xlabel('Date')
    plt.ylabel(pollutant)
    plt.legend()
    plt.tight_layout()  # Automatically adjust layout to fit labels
    plt.show()
# Out:
# 2024-11-20 02:01:17.044764: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_17220/2668593276.py:52: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1156 - val_loss: 0.1174
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0275 - val_loss: 0.0790
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172 - val_loss: 0.0522
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0127 - val_loss: 0.0346
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0117 - val_loss: 0.0262
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - val_loss: 0.0229
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111 - val_loss: 0.0220
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106 - val_loss: 0.0206
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107 - val_loss: 0.0205
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - val_loss: 0.0193
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - val_loss: 0.0200
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - val_loss: 0.0188
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - val_loss: 0.0199
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087 - val_loss: 0.0189
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - val_loss: 0.0195
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - val_loss: 0.0170
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - val_loss: 0.0200
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - val_loss: 0.0181
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - val_loss: 0.0180
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090 - val_loss: 0.0174
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - val_loss: 0.0175
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0183
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - val_loss: 0.0181
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - val_loss: 0.0182
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 0.0175
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - val_loss: 0.0169
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 0.0186
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - val_loss: 0.0187
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - val_loss: 0.0178
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - val_loss: 0.0177
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0170
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0183
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - val_loss: 0.0185
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0175
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0086 - val_loss: 0.0190
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - val_loss: 0.0178
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0078 - val_loss: 0.0173
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0176
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0180
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - val_loss: 0.0172
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - val_loss: 0.0185
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0182
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0190
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - val_loss: 0.0176
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - val_loss: 0.0188
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0185
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0087 - val_loss: 0.0136
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0076 - val_loss: 0.0116
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0075 - val_loss: 0.0120
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0076 - val_loss: 0.0131
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0082 - val_loss: 0.0123
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0079 - val_loss: 0.0127
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0075 - val_loss: 0.0100
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0077 - val_loss: 0.0110
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0078 - val_loss: 0.0110
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0083 - val_loss: 0.0111
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0070 - val_loss: 0.0120
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0081 - val_loss: 0.0096
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073 - val_loss: 0.0117
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065 - val_loss: 0.0110
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0072 - val_loss: 0.0108
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070 - val_loss: 0.0105
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069 - val_loss: 0.0105
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069 - val_loss: 0.0102
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0071 - val_loss: 0.0112
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0077 - val_loss: 0.0102
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0069 - val_loss: 0.0118
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0070 - val_loss: 0.0117
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069 - val_loss: 0.0115
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0079 - val_loss: 0.0116
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0064 - val_loss: 0.0113
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0067 - val_loss: 0.0117
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0072 - val_loss: 0.0124
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0071 - val_loss: 0.0111
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073 - val_loss: 0.0112
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0075 - val_loss: 0.0100
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0074 - val_loss: 0.0107
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0069 - val_loss: 0.0107
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - val_loss: 0.0111
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0072 - val_loss: 0.0129
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0064 - val_loss: 0.0125
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0073 - val_loss: 0.0120
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0066 - val_loss: 0.0147
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0065 - val_loss: 0.0133
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - val_loss: 0.0114
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0072 - val_loss: 0.0142
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0070 - val_loss: 0.0137
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073 - val_loss: 0.0159
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0067 - val_loss: 0.0133
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0069 - val_loss: 0.0128
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0066 - val_loss: 0.0118
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x138618c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_17220/2668593276.py:89: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_17220/2668593276.py:89: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_17220/2668593276.py:89: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0574 - val_loss: 0.0527
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0135 - val_loss: 0.0196
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0122 - val_loss: 0.0206
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0104 - val_loss: 0.0180
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0111 - val_loss: 0.0184
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0108 - val_loss: 0.0176
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0105 - val_loss: 0.0191
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0101 - val_loss: 0.0176
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0102 - val_loss: 0.0196
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0106 - val_loss: 0.0187
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0099 - val_loss: 0.0167
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0100 - val_loss: 0.0188
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0095 - val_loss: 0.0179
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0097 - val_loss: 0.0183
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0090 - val_loss: 0.0196
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.
# SO2 - MSE: 0.046379952972921946, MAE: 0.1710596198766861, RMSE: 0.21536005426476365, R-squared: 0.7062729520473843, MAPE: 128.5786071409225, MBD: -0.1246534089588457, sMAPE: 52.143263447083314
# CO - MSE: 0.00862911201044747, MAE: 0.07180818858877948, RMSE: 0.09289301378708449, R-squared: 0.6722751746870615, MAPE: inf, MBD: -0.03347932372599894, sMAPE: 44.55425188046844
# O3 - MSE: 0.03090119090256418, MAE: 0.14126524933163903, RMSE: 0.17578734568382384, R-squared: 0.8065995684911523, MAPE: 108.72665942611528, MBD: -0.08347358286882926, sMAPE: 40.966225559699495
# NO2 - MSE: 0.0028818015371209816, MAE: 0.043985293221377036, RMSE: 0.05368241366705657, R-squared: 0.10125876359303476, MAPE: inf, MBD: -0.03701765423734514, sMAPE: 101.41942719893201
#
# SARIMA Metrics (only for PM2.5):
# PM2.5 - MSE: 137.9655804116386, MAE: 10.536175110796522, RMSE: 11.745875038141628, R-squared: -19077.277862881863, MAPE: inf, MBD: 10.536175110796522, sMAPE: 195.9253888250127

# %% [markdown]
# ### TangSel Code ALL

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, LSTM, GRU, Dense, SimpleRNN
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pickle

# Load the dataset
data = pd.read_csv('2020-2022_tangsel_cleaned.csv', delimiter=';')

# Convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y', errors='coerce')

# Drop rows with invalid dates
data.dropna(subset=['Date'], inplace=True)

# Set the 'Date' column as the index
data.set_index('Date', inplace=True)

# Replace commas with periods and '-' with NaN, then convert to float
for col in ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']:
    data[col] = data[col].astype(str).str.replace(',', '.').replace('-', np.nan).astype(float)

# Remove rows with 0 data
data = data[(data[['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']] != 0).all(axis=1)]

# Handle NaN values in the numeric columns only
numeric_columns = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')

# Select features and target
features = data[numeric_columns]
target = data[numeric_columns]

# Normalize the features and target
scaler_features = MinMaxScaler()
features_scaled = scaler_features.fit_transform(features)

scaler_target = MinMaxScaler()
target_scaled = scaler_target.fit_transform(target)

# Prepare the data for time series models with sequence length of 5 days
def create_sequences(data, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(target[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 5
X, y = create_sequences(features_scaled, target_scaled, seq_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Function to evaluate the model for each pollutant with additional metrics
def evaluate_model_per_pollutant(y_true, y_pred):
    metrics = {}
    for i, pollutant in enumerate(numeric_columns):
        mse = mean_squared_error(y_true[:, i], y_pred[:, i])
        mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true[:, i], y_pred[:, i])
        mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
        mbd = np.mean(y_pred[:, i] - y_true[:, i])
        smape = 100/len(y_true) * np.sum(2 * np.abs(y_pred[:, i] - y_true[:, i]) / (np.abs(y_true[:, i]) + np.abs(y_pred[:, i])))
        metrics[pollutant] = {'MSE': mse, 'MAE': mae, 'RMSE': rmse, 'R-squared': r2, 'MAPE': mape, 'MBD': mbd, 'sMAPE': smape}
    return metrics

# CNN Model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(seq_length, X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(y.shape[1]))
cnn_model.compile(optimizer='adam', loss='mean_squared_error')
cnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
cnn_predictions_scaled = cnn_model.predict(X_test)
cnn_predictions = scaler_target.inverse_transform(cnn_predictions_scaled)
cnn_metrics = evaluate_model_per_pollutant(y_test, cnn_predictions_scaled)
cnn_model.save('models/tangsel_cnn.h5')

# RNN Model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
rnn_model.add(SimpleRNN(64))
rnn_model.add(Dense(y.shape[1]))
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
rnn_predictions_scaled = rnn_model.predict(X_test)
rnn_predictions = scaler_target.inverse_transform(rnn_predictions_scaled)
rnn_metrics = evaluate_model_per_pollutant(y_test, rnn_predictions_scaled)
rnn_model.save('models/tangsel_rnn.h5')

# GRU Model
gru_model = Sequential()
gru_model.add(GRU(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
gru_model.add(GRU(64))
gru_model.add(Dense(y.shape[1]))
gru_model.compile(optimizer='adam', loss='mean_squared_error')
gru_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
gru_predictions_scaled = gru_model.predict(X_test)
gru_predictions = scaler_target.inverse_transform(gru_predictions_scaled)
gru_metrics = evaluate_model_per_pollutant(y_test, gru_predictions_scaled)
gru_model.save('models/tangsel_gru.h5')

# LSTM Model
lstm_model = Sequential()
lstm_model.add(LSTM(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
lstm_model.add(LSTM(64))
lstm_model.add(Dense(y.shape[1]))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
lstm_predictions_scaled = lstm_model.predict(X_test)
lstm_predictions = scaler_target.inverse_transform(lstm_predictions_scaled)
lstm_metrics = evaluate_model_per_pollutant(y_test, lstm_predictions_scaled)
lstm_model.save('models/tangsel_lstm.h5')

# SARIMA Model (only for PM2.5)
sarima_model = SARIMAX(data['PM2.5'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)
sarima_predictions = sarima_fit.predict(start=len(data) - len(y_test), end=len(data) - 1)
sarima_metrics = {
    'PM2.5': {
        'MSE': mean_squared_error(y_test[:, 0], sarima_predictions),
        'MAE': mean_absolute_error(y_test[:, 0], sarima_predictions),
        'RMSE': np.sqrt(mean_squared_error(y_test[:, 0], sarima_predictions)),
        'R-squared': r2_score(y_test[:, 0], sarima_predictions),
        'MAPE': np.mean(np.abs((y_test[:, 0] - sarima_predictions) / y_test[:, 0])) * 100,
        'MBD': np.mean(sarima_predictions - y_test[:, 0]),
        'sMAPE': 100/len(y_test) * np.sum(2 * np.abs(sarima_predictions - y_test[:, 0]) / (np.abs(y_test[:, 0]) + np.abs(sarima_predictions)))
    }
}
with open('models/tangsel_sarima.pkl', 'wb') as f:
    pickle.dump(sarima_fit, f)

# Print evaluation metrics for each pollutant and model
print("CNN Metrics:")
for pollutant in cnn_metrics:
    print(f"{pollutant} - MSE: {cnn_metrics[pollutant]['MSE']}, MAE: {cnn_metrics[pollutant]['MAE']}, RMSE: {cnn_metrics[pollutant]['RMSE']}, R-squared: {cnn_metrics[pollutant]['R-squared']}, MAPE: {cnn_metrics[pollutant]['MAPE']}, MBD: {cnn_metrics[pollutant]['MBD']}, sMAPE: {cnn_metrics[pollutant]['sMAPE']}")

print("\nRNN Metrics:")
for pollutant in rnn_metrics:
    print(f"{pollutant} - MSE: {rnn_metrics[pollutant]['MSE']}, MAE: {rnn_metrics[pollutant]['MAE']}, RMSE: {rnn_metrics[pollutant]['RMSE']}, R-squared: {rnn_metrics[pollutant]['R-squared']}, MAPE: {rnn_metrics[pollutant]['MAPE']}, MBD: {rnn_metrics[pollutant]['MBD']}, sMAPE: {rnn_metrics[pollutant]['sMAPE']}")

print("\nGRU Metrics:")
for pollutant in gru_metrics:
    print(f"{pollutant} - MSE: {gru_metrics[pollutant]['MSE']}, MAE: {gru_metrics[pollutant]['MAE']}, RMSE: {gru_metrics[pollutant]['RMSE']}, R-squared: {gru_metrics[pollutant]['R-squared']}, MAPE: {gru_metrics[pollutant]['MAPE']}, MBD: {gru_metrics[pollutant]['MBD']}, sMAPE: {gru_metrics[pollutant]['sMAPE']}")

print("\nLSTM Metrics:")
for pollutant in lstm_metrics:
    print(f"{pollutant} - MSE: {lstm_metrics[pollutant]['MSE']}, MAE: {lstm_metrics[pollutant]['MAE']}, RMSE: {lstm_metrics[pollutant]['RMSE']}, R-squared: {lstm_metrics[pollutant]['R-squared']}, MAPE: {lstm_metrics[pollutant]['MAPE']}, MBD: {lstm_metrics[pollutant]['MBD']}, sMAPE: {lstm_metrics[pollutant]['sMAPE']}")

print("\nSARIMA Metrics (only for PM2.5):")
for pollutant in sarima_metrics:
    print(f"{pollutant} - MSE: {sarima_metrics[pollutant]['MSE']}, MAE: {sarima_metrics[pollutant]['MAE']}, RMSE: {sarima_metrics[pollutant]['RMSE']}, R-squared: {sarima_metrics[pollutant]['R-squared']}, MAPE: {sarima_metrics[pollutant]['MAPE']}, MBD: {sarima_metrics[pollutant]['MBD']}, sMAPE: {sarima_metrics[pollutant]['sMAPE']}")

# Plot each pollutant over time and compare actual vs predicted values for test set
pollutants = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
for pollutant in pollutants:
    plt.figure(figsize=(12, 6))
    plt.plot(data.index[-len(X_test):], scaler_target.inverse_transform(y_test)[:, pollutants.index(pollutant)], label=f'Actual {pollutant}')
    plt.plot(data.index[-len(X_test):], cnn_predictions[:, pollutants.index(pollutant)], label=f'CNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], rnn_predictions[:, pollutants.index(pollutant)], label=f'RNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], gru_predictions[:, pollutants.index(pollutant)], label=f'GRU Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], lstm_predictions[:, pollutants.index(pollutant)], label=f'LSTM Predicted {pollutant}')
    if pollutant == 'PM2.5':
        plt.plot(data.index[-len(X_test):], sarima_predictions, label=f'SARIMA Predicted {pollutant}')
    plt.title(f'{pollutant} over Time (Actual vs Predicted)')
    plt.xlabel('Date')
    plt.ylabel(pollutant)
    plt.legend()
    plt.show()
# Out:
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:32: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2621 - val_loss: 0.0960
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0455 - val_loss: 0.0468
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0219 - val_loss: 0.0307
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135 - val_loss: 0.0215
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0099
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0028
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:69: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:69: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.1784 - val_loss: 0.0191
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185 - val_loss: 0.0064
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 0.0041
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 0.0020
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:69: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:69: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0913 - val_loss: 0.0158
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0105 - val_loss: 0.0061
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.9765e-04 - val_loss: 0.0014
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.2340e-04 - val_loss: 0.0014
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.6986e-04 - val_loss: 0.0014
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.6336e-04 - val_loss: 0.0013
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.9956e-04 - val_loss: 0.0013
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3143e-04 - val_loss: 0.0011
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.8373e-04 - val_loss: 0.0014
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.0463e-04 - val_loss: 0.0011
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.8269e-04 - val_loss: 0.0014
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2393e-04 - val_loss: 0.0011
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5446e-04 - val_loss: 0.0011
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.6866e-04 - val_loss: 0.0011
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:69: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_16636/2581856078.py:69: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.1122 - val_loss: 0.0398
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0180 - val_loss: 0.0126
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0052 - val_loss: 0.0066
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0046 - val_loss: 0.0065
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0043 - val_loss: 0.0051
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - val_loss: 0.0042
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - val_loss: 0.0042
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.