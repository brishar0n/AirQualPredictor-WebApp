# %% [markdown]
# #### Jogja Code ALL

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, LSTM, GRU, Dense, SimpleRNN
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Load the datasets
data1 = pd.read_csv('jogja2023.csv', delimiter=';')
data2 = pd.read_csv('jogja2022.csv', delimiter=';')
data3 = pd.read_csv('jogja2021.csv', delimiter=';')
data4 = pd.read_csv('jogja2020.csv')

# Preprocess the data (assuming both datasets have the same structure)
data1['Date'] = pd.to_datetime(data1['Waktu'], format='%d/%m/%Y', errors='coerce')
data2['Date'] = pd.to_datetime(data2['Waktu'], format='%d/%m/%Y', errors='coerce')
data3['Date'] = pd.to_datetime(data3['Waktu'], format='%d/%m/%Y', errors='coerce')
data4['Date'] = pd.to_datetime(data4['Date'], format='%m/%d/%Y', errors='coerce')

# Drop rows with invalid dates
data1.dropna(subset=['Waktu'], inplace=True)
data2.dropna(subset=['Waktu'], inplace=True)
data3.dropna(subset=['Waktu'], inplace=True)
data4.dropna(subset=['Date'], inplace=True)

# Set the 'Date' column as the index for all datasets
data1.set_index('Waktu', inplace=True)
data2.set_index('Waktu', inplace=True)
data3.set_index('Waktu', inplace=True)
data4.set_index('Date', inplace=True)

# Select relevant columns from data4 and rename them to match the other datasets
data4 = data4[['PM10', 'SO2', 'CO', 'O3', 'NO2']]
data4['PM2.5'] = np.nan  # Add PM2.5 column with NaN values to match other datasets

# Concatenate the datasets
data = pd.concat([data1, data2, data3, data4])

# Replace commas with periods and '-' with NaN, then convert to float
for col in ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']:
    data[col] = data[col].astype(str).str.replace(',', '.').replace('-', np.nan).astype(float)

# Remove rows with 0 data
data = data[(data[['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']] != 0).all(axis=1)]

# Handle NaN values in the numeric columns only
numeric_columns = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')

# Select features and target
features = data[numeric_columns]
target = data[numeric_columns]

# Normalize the features and target
scaler_features = MinMaxScaler()
features_scaled = scaler_features.fit_transform(features)

scaler_target = MinMaxScaler()
target_scaled = scaler_target.fit_transform(target)

# Prepare the data for time series models with sequence length of 5 days
def create_sequences(data, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(target[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 5
X, y = create_sequences(features_scaled, target_scaled, seq_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Function to evaluate the model for each pollutant with additional metrics
def evaluate_model_per_pollutant(y_true, y_pred):
    metrics = {}
    for i, pollutant in enumerate(numeric_columns):
        mse = mean_squared_error(y_true[:, i], y_pred[:, i])
        mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true[:, i], y_pred[:, i])
        mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
        mbd = np.mean(y_pred[:, i] - y_true[:, i])
        smape = 100/len(y_true) * np.sum(2 * np.abs(y_pred[:, i] - y_true[:, i]) / (np.abs(y_true[:, i]) + np.abs(y_pred[:, i])))
        metrics[pollutant] = {'MSE': mse, 'MAE': mae, 'RMSE': rmse, 'R-squared': r2, 'MAPE': mape, 'MBD': mbd, 'sMAPE': smape}
    return metrics

# CNN Model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(seq_length, X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(y.shape[1]))
cnn_model.compile(optimizer='adam', loss='mean_squared_error')
cnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
cnn_predictions_scaled = cnn_model.predict(X_test)
cnn_predictions = scaler_target.inverse_transform(cnn_predictions_scaled)
cnn_metrics = evaluate_model_per_pollutant(y_test, cnn_predictions_scaled)

# RNN Model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
rnn_model.add(SimpleRNN(64))
rnn_model.add(Dense(y.shape[1]))
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
rnn_predictions_scaled = rnn_model.predict(X_test)
rnn_predictions = scaler_target.inverse_transform(rnn_predictions_scaled)
rnn_metrics = evaluate_model_per_pollutant(y_test, rnn_predictions_scaled)

# GRU Model
gru_model = Sequential()
gru_model.add(GRU(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
gru_model.add(GRU(64))
gru_model.add(Dense(y.shape[1]))
gru_model.compile(optimizer='adam', loss='mean_squared_error')
gru_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
gru_predictions_scaled = gru_model.predict(X_test)
gru_predictions = scaler_target.inverse_transform(gru_predictions_scaled)
gru_metrics = evaluate_model_per_pollutant(y_test, gru_predictions_scaled)

# LSTM Model
lstm_model = Sequential()
lstm_model.add(LSTM(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
lstm_model.add(LSTM(64))
lstm_model.add(Dense(y.shape[1]))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
lstm_predictions_scaled = lstm_model.predict(X_test)
lstm_predictions = scaler_target.inverse_transform(lstm_predictions_scaled)
lstm_metrics = evaluate_model_per_pollutant(y_test, lstm_predictions_scaled)

# SARIMA Model (only for PM2.5)
sarima_model = SARIMAX(data['PM2.5'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)
sarima_predictions = sarima_fit.predict(start=len(data) - len(y_test), end=len(data) - 1)
sarima_metrics = {
    'PM2.5': {
        'MSE': mean_squared_error(y_test[:, 0], sarima_predictions),
        'MAE': mean_absolute_error(y_test[:, 0], sarima_predictions),
        'RMSE': np.sqrt(mean_squared_error(y_test[:, 0], sarima_predictions)),
        'R-squared': r2_score(y_test[:, 0], sarima_predictions),
        'MAPE': np.mean(np.abs((y_test[:, 0] - sarima_predictions) / y_test[:, 0])) * 100,
        'MBD': np.mean(sarima_predictions - y_test[:, 0]),
        'sMAPE': 100/len(y_test) * np.sum(2 * np.abs(sarima_predictions - y_test[:, 0]) / (np.abs(y_test[:, 0]) + np.abs(sarima_predictions)))
    }
}

# Print evaluation metrics for each pollutant and model
print("CNN Metrics:")
for pollutant in cnn_metrics:
    print(f"{pollutant} - MSE: {cnn_metrics[pollutant]['MSE']}, MAE: {cnn_metrics[pollutant]['MAE']}, RMSE: {cnn_metrics[pollutant]['RMSE']}, R-squared: {cnn_metrics[pollutant]['R-squared']}, MAPE: {cnn_metrics[pollutant]['MAPE']}, MBD: {cnn_metrics[pollutant]['MBD']}, sMAPE: {cnn_metrics[pollutant]['sMAPE']}")

print("\nRNN Metrics:")
for pollutant in rnn_metrics:
    print(f"{pollutant} - MSE: {rnn_metrics[pollutant]['MSE']}, MAE: {rnn_metrics[pollutant]['MAE']}, RMSE: {rnn_metrics[pollutant]['RMSE']}, R-squared: {rnn_metrics[pollutant]['R-squared']}, MAPE: {rnn_metrics[pollutant]['MAPE']}, MBD: {rnn_metrics[pollutant]['MBD']}, sMAPE: {rnn_metrics[pollutant]['sMAPE']}")

print("\nGRU Metrics:")
for pollutant in gru_metrics:
    print(f"{pollutant} - MSE: {gru_metrics[pollutant]['MSE']}, MAE: {gru_metrics[pollutant]['MAE']}, RMSE: {gru_metrics[pollutant]['RMSE']}, R-squared: {gru_metrics[pollutant]['R-squared']}, MAPE: {gru_metrics[pollutant]['MAPE']}, MBD: {gru_metrics[pollutant]['MBD']}, sMAPE: {gru_metrics[pollutant]['sMAPE']}")

print("\nLSTM Metrics:")
for pollutant in lstm_metrics:
    print(f"{pollutant} - MSE: {lstm_metrics[pollutant]['MSE']}, MAE: {lstm_metrics[pollutant]['MAE']}, RMSE: {lstm_metrics[pollutant]['RMSE']}, R-squared: {lstm_metrics[pollutant]['R-squared']}, MAPE: {lstm_metrics[pollutant]['MAPE']}, MBD: {lstm_metrics[pollutant]['MBD']}, sMAPE: {lstm_metrics[pollutant]['sMAPE']}")

print("\nSARIMA Metrics (only for PM2.5):")
for pollutant in sarima_metrics:
    print(f"{pollutant} - MSE: {sarima_metrics[pollutant]['MSE']}, MAE: {sarima_metrics[pollutant]['MAE']}, RMSE: {sarima_metrics[pollutant]['RMSE']}, R-squared: {sarima_metrics[pollutant]['R-squared']}, MAPE: {sarima_metrics[pollutant]['MAPE']}, MBD: {sarima_metrics[pollutant]['MBD']}, sMAPE: {sarima_metrics[pollutant]['sMAPE']}")

# Plot each pollutant over time and compare actual vs predicted values for test set
pollutants = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
for pollutant in pollutants:
    plt.figure(figsize=(12, 6))
    plt.plot(data.index[-len(X_test):], scaler_target.inverse_transform(y_test)[:, pollutants.index(pollutant)], label=f'Actual {pollutant}')
    plt.plot(data.index[-len(X_test):], cnn_predictions[:, pollutants.index(pollutant)], label=f'CNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], rnn_predictions[:, pollutants.index(pollutant)], label=f'RNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], gru_predictions[:, pollutants.index(pollutant)], label=f'GRU Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], lstm_predictions[:, pollutants.index(pollutant)], label=f'LSTM Predicted {pollutant}')
    if pollutant == 'PM2.5':
        plt.plot(data.index[-len(X_test):], sarima_predictions, label=f'SARIMA Predicted {pollutant}')
    plt.title(f'{pollutant} over Time (Actual vs Predicted)')
    plt.xlabel('Date')
    plt.ylabel(pollutant)
    plt.legend()
    plt.show()
# Out:
# 2024-11-19 17:15:54.866565: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0720 - val_loss: 0.1001
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - val_loss: 0.0501
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132 - val_loss: 0.0324
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - val_loss: 0.0244
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108 - val_loss: 0.0218
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - val_loss: 0.0214
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - val_loss: 0.0204
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - val_loss: 0.0212
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - val_loss: 0.0197
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - val_loss: 0.0209
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - val_loss: 0.0197
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - val_loss: 0.0209
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090 - val_loss: 0.0200
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087 - val_loss: 0.0196
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0087 - val_loss: 0.0199
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.0202
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0199
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - val_loss: 0.0205
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - val_loss: 0.0194
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087 - val_loss: 0.0199
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - val_loss: 0.0188
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - val_loss: 0.0221
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0076 - val_loss: 0.0189
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 0.0195
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - val_loss: 0.0187
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - val_loss: 0.0202
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081 - val_loss: 0.0200
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - val_loss: 0.0211
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - val_loss: 0.0186
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - val_loss: 0.0197
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0199
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0208
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0212
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - val_loss: 0.0195
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - val_loss: 0.0204
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0217
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0197
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - val_loss: 0.0224
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - val_loss: 0.0207
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0216
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0204
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - val_loss: 0.0209
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - val_loss: 0.0208
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0203
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0212
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - val_loss: 0.0211
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - val_loss: 0.0230
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0215
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0225
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - val_loss: 0.0223
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.1073 - val_loss: 0.0269
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0160 - val_loss: 0.0234
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0107 - val_loss: 0.0189
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - val_loss: 0.0225
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - val_loss: 0.0190
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0094 - val_loss: 0.0233
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084 - val_loss: 0.0187
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0156
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 0.0159
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - val_loss: 0.0164
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - val_loss: 0.0217
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - val_loss: 0.0185
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080 - val_loss: 0.0233
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - val_loss: 0.0192
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - val_loss: 0.0139
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082 - val_loss: 0.0255
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0130
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082 - val_loss: 0.0167
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - val_loss: 0.0235
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - val_loss: 0.0171
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 0.0161
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - val_loss: 0.0160
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - val_loss: 0.0262
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - val_loss: 0.0141
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - val_loss: 0.0229
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - val_loss: 0.0199
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - val_loss: 0.0154
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - val_loss: 0.0257
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - val_loss: 0.0191
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - val_loss: 0.0167
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0240
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - val_loss: 0.0149
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - val_loss: 0.0174
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0213
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - val_loss: 0.0285
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - val_loss: 0.0178
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0248
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0211
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0282
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - val_loss: 0.0209
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - val_loss: 0.0170
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - val_loss: 0.0220
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - val_loss: 0.0199
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - val_loss: 0.0182
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - val_loss: 0.0220
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - val_loss: 0.0275
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0193
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0168
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - val_loss: 0.0211
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - val_loss: 0.0217
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 0.0465 - val_loss: 0.0225
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0111 - val_loss: 0.0153
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0094 - val_loss: 0.0147
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0091 - val_loss: 0.0131
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0081 - val_loss: 0.0136
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0089 - val_loss: 0.0130
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0079 - val_loss: 0.0120
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0082 - val_loss: 0.0131
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0082 - val_loss: 0.0134
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0080 - val_loss: 0.0111
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0077 - val_loss: 0.0128
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0073 - val_loss: 0.0106
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0071 - val_loss: 0.0108
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0077 - val_loss: 0.0100
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - val_loss: 0.0106
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0084 - val_loss: 0.0098
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0072 - val_loss: 0.0122
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069 - val_loss: 0.0108
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0076 - val_loss: 0.0104
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0068 - val_loss: 0.0101
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0074 - val_loss: 0.0098
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0068 - val_loss: 0.0118
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0067 - val_loss: 0.0110
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0068 - val_loss: 0.0103
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0076 - val_loss: 0.0102
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - val_loss: 0.0113
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0068 - val_loss: 0.0100
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068 - val_loss: 0.0105
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070 - val_loss: 0.0108
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0063 - val_loss: 0.0105
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065 - val_loss: 0.0119
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068 - val_loss: 0.0110
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068 - val_loss: 0.0101
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0067 - val_loss: 0.0108
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0066 - val_loss: 0.0119
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0081 - val_loss: 0.0100
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0072 - val_loss: 0.0110
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0073 - val_loss: 0.0105
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0067 - val_loss: 0.0103
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0068 - val_loss: 0.0105
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073 - val_loss: 0.0119
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0067 - val_loss: 0.0111
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070 - val_loss: 0.0113
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - val_loss: 0.0106
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0065 - val_loss: 0.0120
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069 - val_loss: 0.0121
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0064 - val_loss: 0.0131
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0065 - val_loss: 0.0115
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - val_loss: 0.0117
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x13e47e840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2711554090.py:87: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 0.0678 - val_loss: 0.0635
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0145 - val_loss: 0.0281
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0125 - val_loss: 0.0203
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0124 - val_loss: 0.0207
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0107 - val_loss: 0.0193
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0110 - val_loss: 0.0175
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0110 - val_loss: 0.0195
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0106 - val_loss: 0.0184
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0111 - val_loss: 0.0164
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0106 - val_loss: 0.0165
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0092 - val_loss: 0.0188
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0093 - val_loss: 0.0158
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0099 - val_loss: 0.0179
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0093 - val_loss: 0.0164
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0097 - val_loss: 0.0179
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0094 - val_loss: 0.0167
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0091 - val_loss: 0.0181
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0092 - val_loss: 0.0172
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0087 - val_loss: 0.0169
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0093 - val_loss: 0.0139
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0084 - val_loss: 0.0164
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0083 - val_loss: 0.0164
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0078 - val_loss: 0.0185
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0079 - val_loss: 0.0179
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0077 - val_loss: 0.0151
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0077 - val_loss: 0.0129
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - val_loss: 0.0178
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0080 - val_loss: 0.0138
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0075 - val_loss: 0.0131
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0073 - val_loss: 0.0200
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0076 - val_loss: 0.0157
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0072 - val_loss: 0.0143
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0081 - val_loss: 0.0135
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0070 - val_loss: 0.0132
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0076 - val_loss: 0.0126
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0065 - val_loss: 0.0155
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0073 - val_loss: 0.0143
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0075 - val_loss: 0.0131
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0068 - val_loss: 0.0147
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0072 - val_loss: 0.0140
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0072 - val_loss: 0.0168
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0071 - val_loss: 0.0140
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0074 - val_loss: 0.0179
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0075 - val_loss: 0.0136
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.
# PM10 - MSE: 0.010369026092249538, MAE: 0.07739138247048387, RMSE: 0.10182841495500919, R-squared: 0.38865829057105505, MAPE: 33.83951195634259, MBD: 0.013625628035984114, sMAPE: 28.378555855876076
# SO2 - MSE: 0.01595845103806854, MAE: 0.08737348302511334, RMSE: 0.12632676295254516, R-squared: 0.8989341641625878, MAPE: 98.63633258386349, MBD: -0.03457726062133356, sMAPE: 38.651429915696546
# CO - MSE: 0.008524466156591528, MAE: 0.07122847478724188, RMSE: 0.09232803559369997, R-squared: 0.6762495169059527, MAPE: inf, MBD: -0.034458015764052656, sMAPE: 45.88917089825118
# O3 - MSE: 0.030612423605588187, MAE: 0.1394556662819968, RMSE: 0.17496406375478418, R-squared: 0.8084068684109806, MAPE: 103.92039663862256, MBD: -0.08146553542242768, sMAPE: 40.326856911800306
# NO2 - MSE: 0.0016421858472067787, MAE: 0.032259469637130736, RMSE: 0.04052389230079927, R-squared: 0.48785503799712915, MAPE: inf, MBD: -0.02310305273081776, sMAPE: 74.91220353865468
#
# LSTM Metrics:
# PM2.5 - MSE: 0.0030166461819407463, MAE: 0.042440164277470424, RMSE: 0.05492400369547677, R-squared: 0.5828494766495238, MAPE: inf, MBD: 0.013008548246537363, sMAPE: 45.95574945655538
# PM10 - MSE: 0.011740630348385097, MAE: 0.08410848713997404, RMSE: 0.10835418934395244, R-squared: 0.3077906292163699, MAPE: 38.68446273194237, MBD: 0.027395806548274785, sMAPE: 30.690660220769463
# SO2 - MSE: 0.047558049018782314, MAE: 0.1746361307339765, RMSE: 0.21807808009697424, R-squared: 0.698811998519526, MAPE: 138.5404421093465, MBD: -0.1247020965714146, sMAPE: 53.14112414930466
# CO - MSE: 0.005933907814763234, MAE: 0.05914955010722994, RMSE: 0.0770318623347718, R-squared: 0.7746362662042305, MAPE: inf, MBD: 0.0013410180550587605, sMAPE: 28.795482981684998
# O3 - MSE: 0.025569471359061655, MAE: 0.12432968813526857, RMSE: 0.15990456953777668, R-squared: 0.8399690545944203, MAPE: 124.10206426886674, MBD: -0.05419450483959517, sMAPE: 39.684021500122775
# NO2 - MSE: 0.0017457467925389672, MAE: 0.033818333908176464, RMSE: 0.0417821348489874, R-squared: 0.45555770910323523, MAPE: inf, MBD: 0.018048863278073295, sMAPE: 47.734321509349556
#
# SARIMA Metrics (only for PM2.5):
# PM2.5 - MSE: 137.9655804116386, MAE: 10.536175110796522, RMSE: 11.745875038141628, R-squared: -19077.277862881863, MAPE: inf, MBD: 10.536175110796522, sMAPE: 195.9253888250127

# %% [markdown]
# ### TangSel Code ALL

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, LSTM, GRU, Dense, SimpleRNN
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Load the dataset
data = pd.read_csv('2020-2022_tangsel_cleaned.csv', delimiter=';')

# Convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y', errors='coerce')

# Drop rows with invalid dates
data.dropna(subset=['Date'], inplace=True)

# Set the 'Date' column as the index
data.set_index('Date', inplace=True)

# Replace commas with periods and '-' with NaN, then convert to float
for col in ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']:
    data[col] = data[col].astype(str).str.replace(',', '.').replace('-', np.nan).astype(float)

# Remove rows with 0 data
data = data[(data[['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']] != 0).all(axis=1)]

# Handle NaN values in the numeric columns only
numeric_columns = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')

# Select features and target
features = data[numeric_columns]
target = data[numeric_columns]

# Normalize the features and target
scaler_features = MinMaxScaler()
features_scaled = scaler_features.fit_transform(features)

scaler_target = MinMaxScaler()
target_scaled = scaler_target.fit_transform(target)

# Prepare the data for time series models with sequence length of 5 days
def create_sequences(data, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(target[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 5
X, y = create_sequences(features_scaled, target_scaled, seq_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Function to evaluate the model for each pollutant with additional metrics
def evaluate_model_per_pollutant(y_true, y_pred):
    metrics = {}
    for i, pollutant in enumerate(numeric_columns):
        mse = mean_squared_error(y_true[:, i], y_pred[:, i])
        mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true[:, i], y_pred[:, i])
        mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
        mbd = np.mean(y_pred[:, i] - y_true[:, i])
        smape = 100/len(y_true) * np.sum(2 * np.abs(y_pred[:, i] - y_true[:, i]) / (np.abs(y_true[:, i]) + np.abs(y_pred[:, i])))
        metrics[pollutant] = {'MSE': mse, 'MAE': mae, 'RMSE': rmse, 'R-squared': r2, 'MAPE': mape, 'MBD': mbd, 'sMAPE': smape}
    return metrics

# CNN Model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(seq_length, X.shape[2])))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(y.shape[1]))
cnn_model.compile(optimizer='adam', loss='mean_squared_error')
cnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
cnn_predictions_scaled = cnn_model.predict(X_test)
cnn_predictions = scaler_target.inverse_transform(cnn_predictions_scaled)
cnn_metrics = evaluate_model_per_pollutant(y_test, cnn_predictions_scaled)

# RNN Model
rnn_model = Sequential()
rnn_model.add(SimpleRNN(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
rnn_model.add(SimpleRNN(64))
rnn_model.add(Dense(y.shape[1]))
rnn_model.compile(optimizer='adam', loss='mean_squared_error')
rnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
rnn_predictions_scaled = rnn_model.predict(X_test)
rnn_predictions = scaler_target.inverse_transform(rnn_predictions_scaled)
rnn_metrics = evaluate_model_per_pollutant(y_test, rnn_predictions_scaled)

# GRU Model
gru_model = Sequential()
gru_model.add(GRU(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
gru_model.add(GRU(64))
gru_model.add(Dense(y.shape[1]))
gru_model.compile(optimizer='adam', loss='mean_squared_error')
gru_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
gru_predictions_scaled = gru_model.predict(X_test)
gru_predictions = scaler_target.inverse_transform(gru_predictions_scaled)
gru_metrics = evaluate_model_per_pollutant(y_test, gru_predictions_scaled)

# LSTM Model
lstm_model = Sequential()
lstm_model.add(LSTM(256, return_sequences=True, input_shape=(seq_length, X.shape[2])))
lstm_model.add(LSTM(64))
lstm_model.add(Dense(y.shape[1]))
lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
lstm_predictions_scaled = lstm_model.predict(X_test)
lstm_predictions = scaler_target.inverse_transform(lstm_predictions_scaled)
lstm_metrics = evaluate_model_per_pollutant(y_test, lstm_predictions_scaled)

# SARIMA Model (only for PM2.5)
sarima_model = SARIMAX(data['PM2.5'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
sarima_fit = sarima_model.fit(disp=False)
sarima_predictions = sarima_fit.predict(start=len(data) - len(y_test), end=len(data) - 1)
sarima_metrics = {
    'PM2.5': {
        'MSE': mean_squared_error(y_test[:, 0], sarima_predictions),
        'MAE': mean_absolute_error(y_test[:, 0], sarima_predictions),
        'RMSE': np.sqrt(mean_squared_error(y_test[:, 0], sarima_predictions)),
        'R-squared': r2_score(y_test[:, 0], sarima_predictions),
        'MAPE': np.mean(np.abs((y_test[:, 0] - sarima_predictions) / y_test[:, 0])) * 100,
        'MBD': np.mean(sarima_predictions - y_test[:, 0]),
        'sMAPE': 100/len(y_test) * np.sum(2 * np.abs(sarima_predictions - y_test[:, 0]) / (np.abs(y_test[:, 0]) + np.abs(sarima_predictions)))
    }
}

# Print evaluation metrics for each pollutant and model
print("CNN Metrics:")
for pollutant in cnn_metrics:
    print(f"{pollutant} - MSE: {cnn_metrics[pollutant]['MSE']}, MAE: {cnn_metrics[pollutant]['MAE']}, RMSE: {cnn_metrics[pollutant]['RMSE']}, R-squared: {cnn_metrics[pollutant]['R-squared']}, MAPE: {cnn_metrics[pollutant]['MAPE']}, MBD: {cnn_metrics[pollutant]['MBD']}, sMAPE: {cnn_metrics[pollutant]['sMAPE']}")

print("\nRNN Metrics:")
for pollutant in rnn_metrics:
    print(f"{pollutant} - MSE: {rnn_metrics[pollutant]['MSE']}, MAE: {rnn_metrics[pollutant]['MAE']}, RMSE: {rnn_metrics[pollutant]['RMSE']}, R-squared: {rnn_metrics[pollutant]['R-squared']}, MAPE: {rnn_metrics[pollutant]['MAPE']}, MBD: {rnn_metrics[pollutant]['MBD']}, sMAPE: {rnn_metrics[pollutant]['sMAPE']}")

print("\nGRU Metrics:")
for pollutant in gru_metrics:
    print(f"{pollutant} - MSE: {gru_metrics[pollutant]['MSE']}, MAE: {gru_metrics[pollutant]['MAE']}, RMSE: {gru_metrics[pollutant]['RMSE']}, R-squared: {gru_metrics[pollutant]['R-squared']}, MAPE: {gru_metrics[pollutant]['MAPE']}, MBD: {gru_metrics[pollutant]['MBD']}, sMAPE: {gru_metrics[pollutant]['sMAPE']}")

print("\nLSTM Metrics:")
for pollutant in lstm_metrics:
    print(f"{pollutant} - MSE: {lstm_metrics[pollutant]['MSE']}, MAE: {lstm_metrics[pollutant]['MAE']}, RMSE: {lstm_metrics[pollutant]['RMSE']}, R-squared: {lstm_metrics[pollutant]['R-squared']}, MAPE: {lstm_metrics[pollutant]['MAPE']}, MBD: {lstm_metrics[pollutant]['MBD']}, sMAPE: {lstm_metrics[pollutant]['sMAPE']}")

print("\nSARIMA Metrics (only for PM2.5):")
for pollutant in sarima_metrics:
    print(f"{pollutant} - MSE: {sarima_metrics[pollutant]['MSE']}, MAE: {sarima_metrics[pollutant]['MAE']}, RMSE: {sarima_metrics[pollutant]['RMSE']}, R-squared: {sarima_metrics[pollutant]['R-squared']}, MAPE: {sarima_metrics[pollutant]['MAPE']}, MBD: {sarima_metrics[pollutant]['MBD']}, sMAPE: {sarima_metrics[pollutant]['sMAPE']}")

# Plot each pollutant over time and compare actual vs predicted values for test set
pollutants = ['PM2.5', 'PM10', 'SO2', 'CO', 'O3', 'NO2']
for pollutant in pollutants:
    plt.figure(figsize=(12, 6))
    plt.plot(data.index[-len(X_test):], scaler_target.inverse_transform(y_test)[:, pollutants.index(pollutant)], label=f'Actual {pollutant}')
    plt.plot(data.index[-len(X_test):], cnn_predictions[:, pollutants.index(pollutant)], label=f'CNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], rnn_predictions[:, pollutants.index(pollutant)], label=f'RNN Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], gru_predictions[:, pollutants.index(pollutant)], label=f'GRU Predicted {pollutant}')
    plt.plot(data.index[-len(X_test):], lstm_predictions[:, pollutants.index(pollutant)], label=f'LSTM Predicted {pollutant}')
    if pollutant == 'PM2.5':
        plt.plot(data.index[-len(X_test):], sarima_predictions, label=f'SARIMA Predicted {pollutant}')
    plt.title(f'{pollutant} over Time (Actual vs Predicted)')
    plt.xlabel('Date')
    plt.ylabel(pollutant)
    plt.legend()
    plt.show()
# Out:
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:31: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[numeric_columns] = data[numeric_columns].fillna(method='ffill').fillna(method='bfill')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1876 - val_loss: 0.0522
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0353 - val_loss: 0.0310
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0219 - val_loss: 0.0179
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0117 - val_loss: 0.0134
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - val_loss: 0.0096
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - val_loss: 0.0043
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0027
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:68: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:68: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.2287 - val_loss: 0.0355
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0212 - val_loss: 0.0121
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0073
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0053
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0047
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 0.0016
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:68: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:68: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.0881 - val_loss: 0.0163
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0111 - val_loss: 0.0065
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 24/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 25/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 26/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 27/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 28/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 29/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 30/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 31/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 32/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 33/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 34/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.6027e-04 - val_loss: 0.0013
# Epoch 35/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.8387e-04 - val_loss: 0.0015
# Epoch 36/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 37/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 38/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8027e-04 - val_loss: 0.0014
# Epoch 40/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 41/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.6579e-04 - val_loss: 0.0015
# Epoch 42/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 43/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4289e-04 - val_loss: 0.0014
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.1540e-04 - val_loss: 0.0013
# Epoch 45/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 46/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.1752e-04 - val_loss: 0.0013
# Epoch 47/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.4615e-04 - val_loss: 0.0012
# Epoch 48/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6945e-04 - val_loss: 0.0013
# Epoch 49/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.0437e-04 - val_loss: 0.0013
# Epoch 50/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0951e-04 - val_loss: 0.0013
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step
# Epoch 1/50
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:68: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /var/folders/p7/86ppfgbj07x6_19c70ypq6qw0000gn/T/ipykernel_4291/2142009044.py:68: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((y_true[:, i] - y_pred[:, i]) / y_true[:, i])) * 100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.1158 - val_loss: 0.0322
# Epoch 2/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0213 - val_loss: 0.0135
# Epoch 3/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0086 - val_loss: 0.0074
# Epoch 4/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0054 - val_loss: 0.0062
# Epoch 5/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 6/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 7/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 8/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 9/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 10/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 11/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 12/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 0.0046
# Epoch 13/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 14/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035 - val_loss: 0.0047
# Epoch 15/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 16/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 17/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - val_loss: 0.0048
# Epoch 18/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 19/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 20/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 21/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 22/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029 - val_loss: 0.0046
# Epoch 23/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 